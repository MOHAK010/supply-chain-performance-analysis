# %% [markdown]
# # Supply Chain & Logistics Analytics
#
# ## Notebook 1 - Data Loading & Cleaning
#
# This notebook focuses on loading all datasets, checking data quality, and preparing clean data for SQL analysis and Power BI dashboard development.

# %% [markdown]
# In this notebook, the datasets are loaded and checked for common data quality issues before moving to analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.set_option("display.max_columns", None)

# Display more rows while exploring data
pd.set_option("display.max_rows", 100)

# %% [markdown]
# ## Define Dataset Path

# %%
# Location of raw csv files
DATA_PATH = "../data/raw/"

# %% [markdown]
# ## Load All Datasets

# %%
customers = pd.read_csv("../Dataset/customers.csv")
orders = pd.read_csv( "../Dataset/orders.csv")
products = pd.read_csv("../Dataset/products.csv")
suppliers = pd.read_csv("../Dataset/suppliers.csv")
warehouses = pd.read_csv("../Dataset/warehouses.csv")
inventory = pd.read_csv("../Dataset/inventory.csv")
shipments = pd.read_csv("../Dataset/shipments.csv")
returns = pd.read_csv("../Dataset/returns.csv")

# %% [markdown]
# ## Verify Dataset Loading

# %%
datasets = {
    "Customers": customers,
    "Orders": orders,
    "Products": products,
    "Suppliers": suppliers,
    "Warehouses": warehouses,
    "Inventory": inventory,
    "Shipments": shipments,
    "Returns": returns
}

for name, df in datasets.items():
    print(f"{name:<12} : {df.shape[0]} rows × {df.shape[1]} columns")
# Out:
# Customers    : 800 rows × 4 columns
# Orders       : 10000 rows × 7 columns
# Products     : 120 rows × 5 columns
# Suppliers    : 25 rows × 4 columns
# Warehouses   : 8 rows × 3 columns
# Inventory    : 960 rows × 4 columns
# Shipments    : 10000 rows × 6 columns
# Returns      : 802 rows × 4 columns

# %% [markdown]
# ## Preview the Data
#
# Let's take a quick look at each dataset before checking data quality.

# %% [markdown]
# ## Quick Preview
#
# Before performing any cleaning, let's inspect the datasets to understand their structure and available columns.

# %%
# Preview customer dataset
customers.head()
# Out:
#    customer_id customer_name region    segment
# 0            1    Customer_1  South     Retail
# 1            2    Customer_2   East  Wholesale
# 2            3    Customer_3   West  Corporate
# 3            4    Customer_4   West  Corporate
# 4            5    Customer_5  North     Retail

# %%
# Preview orders dataset
orders.head()
# Out:
#    order_id  order_date  customer_id  product_id  warehouse_id  quantity  \
# 0     10001  2025-09-06          700          21             6        20
# 1     10002  2025-04-18          187           6             8        14
# 2     10003  2025-01-05          155         117             5        17
# 3     10004  2025-02-16          344          44             7         2
# 4     10005  2025-10-22          746          90             2         1
#
#    unit_price
# 0      421.40
# 1      446.02
# 2      912.30
# 3      198.04
# 4      100.40

# %%
# Preview products dataset
products.head()
# Out:
#    product_id product_name     category  supplier_id  unit_cost
# 0           1    Product_1         Home           22        439
# 1           2    Product_2    Furniture           25        207
# 2           3    Product_3       Sports           16         30
# 3           4    Product_4  Electronics            9        128
# 4           5    Product_5       Office            6        576

# %%
# Preview suppliers dataset
suppliers.head()
# Out:
#    supplier_id supplier_name  country  rating
# 0            1    Supplier_1  Vietnam       3
# 1            2    Supplier_2  Germany       2
# 2            3    Supplier_3    India       2
# 3            4    Supplier_4  Vietnam       2
# 4            5    Supplier_5      UAE       3

# %%
# Preview warehouses dataset
warehouses.head()
# Out:
#    warehouse_id warehouse_city  capacity
# 0             1          Delhi     14593
# 1             2         Mumbai     12424
# 2             3      Bengaluru     10924
# 3             4      Hyderabad      9911
# 4             5        Kolkata      9070

# %%
# Preview inventory dataset
inventory.head()
# Out:
#    product_id  warehouse_id  stock_qty  reorder_level
# 0           1             1         35            138
# 1           1             2        635            179
# 2           1             3        618            209
# 3           1             4        272            196
# 4           1             5        416            275

# %%
# Preview shipments dataset
shipments.head()
# Out:
#    shipment_id  order_id shipping_mode delivery_date delivery_status  \
# 0        50001     10001          Road    2025-09-11         Delayed
# 1        50002     10002          Road    2025-04-25       Delivered
# 2        50003     10003           Air    2025-01-09       Delivered
# 3        50004     10004          Rail    2025-02-24       Delivered
# 4        50005     10005          Road    2025-10-30       Delivered
#
#    shipping_cost
# 0          14.54
# 1          35.83
# 2          38.81
# 3          40.65
# 4           7.91

# %%
# Preview returns dataset
returns.head()
# Out:
#    return_id  order_id  return_reason  returned_qty
# 0       9001     10004        Damaged             1
# 1       9002     10015  Late Delivery             6
# 2       9003     10020        Damaged             5
# 3       9004     10043  Late Delivery             1
# 4       9005     10056  Late Delivery             6

# %% [markdown]
# ## Dataset Information
#
# Checking the structure of each dataset including data types, null values, and memory usage.

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    800 non-null    int64
#  1   customer_name  800 non-null    object
#  2   region         800 non-null    object
#  3   segment        800 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 25.1+ KB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      10000 non-null  int64
#  1   order_date    10000 non-null  object
#  2   customer_id   10000 non-null  int64
#  3   product_id    10000 non-null  int64
#  4   warehouse_id  10000 non-null  int64
#  5   quantity      10000 non-null  int64
#  6   unit_price    10000 non-null  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 547.0+ KB

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    120 non-null    int64
#  1   product_name  120 non-null    object
#  2   category      120 non-null    object
#  3   supplier_id   120 non-null    int64
#  4   unit_cost     120 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.8+ KB

# %%
suppliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   supplier_id    25 non-null     int64
#  1   supplier_name  25 non-null     object
#  2   country        25 non-null     object
#  3   rating         25 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 932.0+ bytes

# %%
warehouses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   warehouse_id    8 non-null      int64
#  1   warehouse_city  8 non-null      object
#  2   capacity        8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %% [markdown]
# ## Remaining Dataset Information

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     960 non-null    int64
#  1   warehouse_id   960 non-null    int64
#  2   stock_qty      960 non-null    int64
#  3   reorder_level  960 non-null    int64
# dtypes: int64(4)
# memory usage: 30.1 KB

# %%
shipments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   shipment_id      10000 non-null  int64
#  1   order_id         10000 non-null  int64
#  2   shipping_mode    10000 non-null  object
#  3   delivery_date    10000 non-null  object
#  4   delivery_status  10000 non-null  object
#  5   shipping_cost    10000 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 468.9+ KB

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 802 entries, 0 to 801
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   return_id      802 non-null    int64
#  1   order_id       802 non-null    int64
#  2   return_reason  802 non-null    object
#  3   returned_qty   802 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 25.2+ KB

# %% [markdown]
# ## Summary Statistics
#
# Let's review the numerical columns available in each dataset.

# %%
for name, df in datasets.items():
    print(f"\n{'='*60}")
    print(name.upper())
    print('='*60)
    display(df.describe(include="all"))
# Out:
# ...
# CUSTOMERS
# ...
#         customer_id customer_name region segment
# count      800.0000           800    800     800
# unique          NaN           800      4       3
# top             NaN    Customer_1  South  Retail
# freq            NaN             1    216     296
# mean       400.5000           NaN    NaN     NaN
# std        231.0844           NaN    NaN     NaN
# min          1.0000           NaN    NaN     NaN
# 25%        200.7500           NaN    NaN     NaN
# 50%        400.5000           NaN    NaN     NaN
# 75%        600.2500           NaN    NaN     NaN
# max        800.0000           NaN    NaN     NaN
# ...
# ORDERS
# ...
#            order_id  order_date   customer_id   product_id  warehouse_id  \
# count   10000.00000       10000  10000.000000  10000.00000  10000.000000
# unique          NaN         365           NaN          NaN           NaN
# top             NaN  2025-12-13           NaN          NaN           NaN
# ...

# %% [markdown]
# ## Missing Values

# %%
missing_values = pd.DataFrame({
    "Missing Values": customers.isnull().sum(),
    "Percentage": round((customers.isnull().sum()/len(customers))*100,2)
})

missing_values
# Out:
#                Missing Values  Percentage
# customer_id                 0         0.0
# customer_name               0         0.0
# region                      0         0.0
# segment                     0         0.0

# %%
for name, df in datasets.items():
    print(f"\n{name}")
    display(df.isnull().sum())
# Out:
# Customers
# customer_id      0
# customer_name    0
# region           0
# segment          0
# dtype: int64
# Orders
# order_id        0
# order_date      0
# customer_id     0
# product_id      0
# warehouse_id    0
# quantity        0
# unit_price      0
# dtype: int64
# Products
# product_id      0
# product_name    0
# category        0
# supplier_id     0
# unit_cost       0
# dtype: int64
# Suppliers
# supplier_id      0
# supplier_name    0
# country          0
# rating           0
# dtype: int64
# Warehouses
# warehouse_id      0
# warehouse_city    0
# capacity          0
# dtype: int64
# Inventory
# product_id       0
# warehouse_id     0
# stock_qty        0
# reorder_level    0
# dtype: int64
# Shipments
# shipment_id        0
# order_id           0
# shipping_mode      0
# delivery_date      0
# delivery_status    0
# shipping_cost      0
# dtype: int64
# Returns
# return_id        0
# order_id         0
# return_reason    0
# returned_qty     0
# dtype: int64

# %% [markdown]
# ## Duplicate Records

# %%
for name, df in datasets.items():
    print(f"{name:<12} : {df.duplicated().sum()} duplicate rows")
# Out:
# Customers    : 0 duplicate rows
# Orders       : 0 duplicate rows
# Products     : 0 duplicate rows
# Suppliers    : 0 duplicate rows
# Warehouses   : 0 duplicate rows
# Inventory    : 0 duplicate rows
# Shipments    : 0 duplicate rows
# Returns      : 0 duplicate rows

# %% [markdown]
# ### Initial Observations
#
# - Dataset loading completed successfully.
# - Data types look consistent across most tables.
# - Missing values and duplicates have been identified.
# - The next step is to clean and standardize the datasets before analysis.

# %%
# Save current copies before cleaning (optional backup)

customers_raw = customers.copy()
orders_raw = orders.copy()
products_raw = products.copy()
suppliers_raw = suppliers.copy()
warehouses_raw = warehouses.copy()
inventory_raw = inventory.copy()
shipments_raw = shipments.copy()
returns_raw = returns.copy()

# %% [markdown]
# ## Summary Statistics
#
# Let's review the numerical and categorical information available in each dataset.

# %%
for name, df in datasets.items():
    print("=" * 70)
    print(f"{name.upper()} DATASET")
    print("=" * 70)

    display(df.describe(include="all"))
# Out:
# ...
# CUSTOMERS DATASET
# ...
#         customer_id customer_name region segment
# count      800.0000           800    800     800
# unique          NaN           800      4       3
# top             NaN    Customer_1  South  Retail
# freq            NaN             1    216     296
# mean       400.5000           NaN    NaN     NaN
# std        231.0844           NaN    NaN     NaN
# min          1.0000           NaN    NaN     NaN
# 25%        200.7500           NaN    NaN     NaN
# 50%        400.5000           NaN    NaN     NaN
# 75%        600.2500           NaN    NaN     NaN
# max        800.0000           NaN    NaN     NaN
# ...
# ORDERS DATASET
# ...
#            order_id  order_date   customer_id   product_id  warehouse_id  \
# count   10000.00000       10000  10000.000000  10000.00000  10000.000000
# unique          NaN         365           NaN          NaN           NaN
# top             NaN  2025-12-13           NaN          NaN           NaN
# ...

# %% [markdown]
# ## Unique Values

# %%
for name, df in datasets.items():

    print("=" * 70)
    print(name.upper())
    print("=" * 70)

    display(df.nunique().sort_values())
# Out:
# ...
# CUSTOMERS
# ...
# segment            3
# region             4
# customer_id      800
# customer_name    800
# dtype: int64
# ...
# ORDERS
# ...
# warehouse_id        8
# quantity           25
# product_id        120
# order_date        365
# customer_id       800
# unit_price       9526
# order_id        10000
# dtype: int64
# ...
# PRODUCTS
# ...
# category          5
# supplier_id      25
# unit_cost       107
# product_id      120
# product_name    120
# dtype: int64
# ...
# SUPPLIERS
# ...
# rating            4
# country           5
# supplier_id      25
# supplier_name    25
# dtype: int64
# ...
# WAREHOUSES
# ...
# warehouse_id      8
# warehouse_city    8
# capacity          8
# dtype: int64
# ...
# INVENTORY
# ...
# warehouse_id       8
# product_id       120
# reorder_level    199
# stock_qty        549
# dtype: int64
# ...
# SHIPMENTS
# ...
# delivery_status        2
# shipping_mode          3
# delivery_date        372
# shipping_cost       4015
# shipment_id        10000
# order_id           10000
# dtype: int64
# ...
# RETURNS
# ...
# return_reason      3
# ...

# %% [markdown]
# ## Standardize Data Types

# %%
# Convert date columns

orders["order_date"] = pd.to_datetime(orders["order_date"])

shipments["delivery_date"] = pd.to_datetime(
    shipments["delivery_date"]
)

# %% [markdown]
# ## Verify Updated Data Types

# %%
print(orders.dtypes)

print("-" * 60)

print(shipments.dtypes)
# Out:
# order_id                 int64
# order_date      datetime64[ns]
# customer_id              int64
# product_id               int64
# warehouse_id             int64
# quantity                 int64
# unit_price             float64
# dtype: object
# ------------------------------------------------------------
# shipment_id                 int64
# order_id                    int64
# shipping_mode              object
# delivery_date      datetime64[ns]
# delivery_status            object
# shipping_cost             float64
# dtype: object

# %% [markdown]
# ## Verify Updated Data Types

# %% [markdown]
# ## Key Takeaways
#
# - All datasets were loaded successfully without any loading issues.
# - The overall data quality is good, with very few missing or duplicate records.
# - Date columns were converted to the appropriate format for future analysis.
# - The datasets are now clean and ready for exploratory data analysis (EDA), where trends, patterns, and business insights will be identified.

# %% [markdown]
# ## Conclusion
#
# The datasets were successfully prepared for analysis. Initial inspection shows that the data is well-structured with minimal quality issues. Since the raw data is now validated and organized, the next step is to explore trends, identify patterns, and generate business insights through exploratory data analysis.
